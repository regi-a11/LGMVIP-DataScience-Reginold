# %% [markdown]
# # Let's Grow More (LGMVIP) - "DATA SCIENCE INTERN"

# %% [markdown]
# <font size="4">Author Reginold K Binoy</font>

# %% [markdown]
# ## BEGINNER LEVEL TASK

# %% [markdown]
# ### Task 4 -Image to Pencil Sketch with Python

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np

# %% [markdown]
# # Function to convert image to pencil sketch

# %%
def convert_to_sketch(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    inverted_image = 255 - gray_image
    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
    inverted_blurred = 255 - blurred_image
    pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
    return gray_image, cv2.cvtColor(pencil_sketch, cv2.COLOR_GRAY2BGR)

# %% [markdown]
# # Loading images

# %%
image1 = cv2.imread("sukuna.jpg")
image2 = cv2.imread("gojo.jfif")

# %% [markdown]
# # Converting both images to grayscale and pencil sketches

# %%
gray_image1, pencil_sketch1 = convert_to_sketch(image1)
gray_image2, pencil_sketch2 = convert_to_sketch(image2)

# %% [markdown]
# # Resizing images to the same height

# %%
def resize_to_same_height(*images):
    # Get the height of the first image
    height = images[0].shape[0]
    # Resize all images to the same height
    resized_images = [cv2.resize(img, (int(img.shape[1] * height / img.shape[0]), height)) for img in images]
    return resized_images

# %% [markdown]
# # Resizing images again

# %%
resized_image1, resized_pencil_sketch1, resized_image2, resized_pencil_sketch2 = resize_to_same_height(image1, pencil_sketch1, image2, pencil_sketch2)

# %% [markdown]
# # Concatenating the images horizontally

# %%
concatenated_image = cv2.hconcat([resized_image1, resized_pencil_sketch1, resized_image2, resized_pencil_sketch2])

# %% [markdown]
# # Displaying the concatenated image

# %%
cv2.imshow("Original and Sketches", concatenated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cv2.imshow("Original and Sketches", concatenated_image)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# # Result

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename='/Users/reginoldkbinoy/Desktop/LGMVIP-DataScience-Reginold/Task 4/result.png'))

# %% [markdown]
# # Thank You
